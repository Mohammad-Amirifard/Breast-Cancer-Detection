# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-Amirifard/Breast-Cancer-Detection/blob/main/Part1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1- Connect Colab to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive') # mount google drive to /content directory. You can see your drive on the left pannel.
# Out:
# Mounted at /content/drive

# %%
# Copy SIIT Project to /content direcory
# %cp -r /content/drive/MyDrive/Projects/SIIT /content/
# Out:
# cp: cannot open '/content/drive/MyDrive/Projects/SIIT/Reports/1st idea report.gdoc' for reading: Operation not supported
# cp: cannot open '/content/drive/MyDrive/Projects/SIIT/Reports/2nd idea report.gdoc' for reading: Operation not supported

# %% [markdown]
# ###2- Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###3- Load data

# %%
Ass_data = pd.read_csv('/content/SIIT/Dataset/Ass.csv')
Ass_data.head()
# Out:
# <ipython-input-10-f0cf7206d8b8>:1: DtypeWarning: Columns (0,8,20,22,28,29,34,38,39,44,51,69,104,107,108,122,123,127,144,153,154,163,164,165,167,168,170,171,172,174,175,176,177,178,181,182,183,184,185,186,187,188,189,190,191,192,195,197,198,207,208,209,211,212,213,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   Ass_data = pd.read_csv('/content/SIIT/Dataset/Ass.csv')
#   Ass.Famiglia Prod Ass.KEY_STB_IDF  Ass.Stabilimento anag  \
# 0                36     01|03009574                    1.0
# 1                36     01|03011116                    1.0
# 2                36     01|03009575                    1.0
# 3                36     01|03009576                    1.0
# 4                36     01|03009573                    1.0
#
#   Ass.Codice Prodotto anag Ass.Disegno Cli  \
# 0                 03009574        03009574
# 1                 03011116        03011116
# 2                 03009575        03009575
# ...
